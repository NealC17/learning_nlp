# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('eng_-french.csv')

# %%
df.head()
# Out:
#   English words/sentences French words/sentences
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !

# %%
df.tail()
# Out:
#                                   English words/sentences  \
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                    French words/sentences
# 175616  « L'économie en partant du haut vers le bas, ç...
# 175617  Une empreinte carbone est la somme de pollutio...
# 175618  La mort est une chose qu'on nous décourage sou...
# 175619  Puisqu'il y a de multiples sites web sur chaqu...
# 175620  Si quelqu'un qui ne connaît pas vos antécédent...

# %%
df.tail()['French words/sentences'].tolist()[0]
# Out:
# "« L'économie en partant du haut vers le bas, ça ne marche jamais, » a dit Obama. « Le pays ne réussit pas lorsque seulement ceux qui sont au sommet s'en sortent bien. Nous réussissons lorsque la classe moyenne s'élargit, lorsqu'elle se sent davantage en sécurité. »"

# %%
df = df.replace({
    "\u202f": " ",
    "\xa0": " ",
    "\ufeff": "",
    "\u200b": "",
}, regex=True)

# %%
df.head()
# Out:
#   English words/sentences French words/sentences
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !

# %%
df.tail()
# Out:
#                                   English words/sentences  \
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                    French words/sentences
# 175616  « L'économie en partant du haut vers le bas, ç...
# 175617  Une empreinte carbone est la somme de pollutio...
# 175618  La mort est une chose qu'on nous décourage sou...
# 175619  Puisqu'il y a de multiples sites web sur chaqu...
# 175620  Si quelqu'un qui ne connaît pas vos antécédent...

# %%
len(df)
# Out:
# 175621

# %%
import torch
device = 'mps' if torch.mps.is_available() else ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'mps'

# %%
from torch.utils.data import DataLoader, Dataset
class FRDataset(Dataset):
    def __init__(self, df):
        super().__init__()
        self.df = df


    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        x, y = self.df.iloc[idx]
        return x, y

dataset = FRDataset(df)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
#next(iter(dataloader))

# %%
import nltk
#nltk.download("punkt_tab")

from nltk.tokenize import word_tokenize

a, b = df.iloc[0]
print(a, b, type(a), type(b))
print(word_tokenize(a))
print(word_tokenize(b, language='french'))
# Out:
# Hi. Salut! <class 'str'> <class 'str'>
# ['Hi', '.']
# ['Salut', '!']

# %%
#vocab_en = (((''.join(df['English words/sentences'].iloc[:]))))
#vocab_fr = (((''.join(df['French words/sentences'].iloc[:]))))

#vocab_en = vocab_en.replace('.', '. ')
#vocab_en = vocab_en.replace('\\'+ '\'', '\'')

#vocab_fr = vocab_fr.replace('.', '. ')
#vocab_fr = vocab_fr.replace('\\' + '\'', '\'')

#vocab_en = word_tokenize(vocab_en, language='english')
#vocab_fr = word_tokenize(vocab_fr, language='french')
